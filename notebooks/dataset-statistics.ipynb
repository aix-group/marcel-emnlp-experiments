# %%
import pandas as pd
import nltk

# %% [markdown]
# ## Statistics of knowledgebase

# %%
df_documents = pd.read_json('../data/crawls/20250317/data.jsonl', lines=True)
df_documents.head()
# Out:
#                                                  url  status  \
# 0  https://www.uni-marburg.de/en/studying/degree-...     200
# 1  https://www.mathematik.uni-marburg.de/modulhan...     200
# 2        https://studentenwerk-marburg.de/en/living/     200
# 3  https://www.uni-marburg.de/en/studying/admissi...     200
# 4    https://studentenwerk-marburg.de/en/living/faq/     200
#
#                                                 html  \
# 0  <!DOCTYPE html>\n<html xmlns="http://www.w3.or...
# 1  \n\n\n\n<!DOCTYPE html>\n<html xmlns:xlink="ht...
# 2  <!DOCTYPE html>\n<html lang="en-US" class="no-...
# 3  <!DOCTYPE html>\n<html xmlns="http://www.w3.or...
# 4  <!DOCTYPE html>\n<html lang="en-US" class="no-...
#
#                                              content  \
# 0  ###### Main Content\n\n# Data Science (Master ...
# 1  ###### Main content\n\n# **M.Sc. Data Science*...
# 2  Welcome to Marburg! The Studentenwerk Marburg ...
# 3  # Admissions\n\nFor a successful start to your...
# 4  # FAQ\n\n**How expensive is an apartment / sin...
#
#                                                   og
# 0  {'og:site_name': 'Philipps-Universität Marburg...
# 1  {'og:site_name': 'Philipps-Universität Marburg...
# 2                                                 {}
# 3  {'og:site_name': 'Philipps-Universität Marburg...
# 4                                                 {}

# %%
len(df_documents)
# Out:
# 249

# %%
df_documents['content'].apply(nltk.word_tokenize).apply(len).describe()
# Out:
# count     249.000000
# mean      712.955823
# std       486.027713
# min        13.000000
# 25%       479.000000
# 50%       688.000000
# 75%       816.000000
# max      3678.000000
# Name: content, dtype: float64

# %% [markdown]
# ## Statistics of test queries

# %% [markdown]
# all / answerable / unanswerable
# - n
# - question length
# - answer length
# - number of sources

# %%
df_queries = pd.read_json('../data/queries/20250317-email.json')
df_queries['question_length'] = df_queries['question'].apply(nltk.word_tokenize).apply(len)
df_queries['intent_length'] = df_queries['intent'].apply(nltk.word_tokenize).apply(len)
df_queries['reference_answer_length'] = df_queries['reference_answer'].apply(nltk.word_tokenize).apply(len)
df_queries['sources_length'] = df_queries['sources'].apply(len)
df_queries['answerable'] = df_queries['sources'].apply(len) >= 1
df_queries.head()
# Out:
#          id                 category  \
# 0  faq-0000  01 - Admission Criteria
# 1  faq-0001  01 - Admission Criteria
# 2  faq-0002  01 - Admission Criteria
# 3  faq-0003  01 - Admission Criteria
# 4  faq-0004  01 - Admission Criteria
#
#                                      intent  \
# 0  Given my background, will I be accepted?
# 1  Given my background, will I be accepted?
# 2  Given my background, will I be accepted?
# 3  Given my background, will I be accepted?
# 4  Given my background, will I be accepted?
#
#                                             question  \
# 0  I want to inquire about the acceptance criteri...
# 1  I recently completed my undergraduate degree i...
# 2  My cgpa is 6.4 but while I pursuing my BCA I  ...
# 3  I have completed my Bachelor's degree in Compu...
# 4  I would like to inquire about the eligibility ...
#
#                                     reference_answer  \
# 0  Your bachelor degree needs to be in Data Scien...
# 1  Your bachelor degree needs to be in Data Scien...
# 2  Your bachelor degree needs to be in Data Scien...
# 3  Your bachelor degree needs to be in Data Scien...
# 4  Your bachelor degree needs to be in Data Scien...
#
#                                              sources  question_length  \
# 0  [https://www.uni-marburg.de/en/studying/degree...              103
# 1  [https://www.uni-marburg.de/en/studying/degree...               64
# 2  [https://www.uni-marburg.de/en/studying/degree...               60
# 3  [https://www.uni-marburg.de/en/studying/degree...               27
# 4  [https://www.uni-marburg.de/en/studying/degree...               27
#
#    intent_length  reference_answer_length  sources_length  answerable
# 0              9                       81               1        True
# 1              9                       81               1        True
# 2              9                       81               1        True
# 3              9                       81               1        True
# 4              9                       81               1        True

# %%
stats = df_queries.groupby('answerable').agg(
    n=('answerable', 'size'),
    intent=('intent', 'nunique'),
    avg_intent_length=('intent_length', 'mean'),
    avg_question_length=('question_length', 'mean'),
    avg_answer_length=('reference_answer_length', 'mean'),
    avg_sources_length=('sources_length', 'mean'),
)
stats.loc['all'] = {
    'n': len(df_queries),
    'intent': df_queries['intent'].nunique(),
    'avg_intent_length': df_queries['intent_length'].mean(),
    'avg_question_length': df_queries['question_length'].mean(),
    'avg_answer_length': df_queries['reference_answer_length'].mean(),
    'avg_sources_length': df_queries['sources_length'].mean(),
}
stats = stats.rename({
    'all': 'All',
    True: 'Answerable',
    False: 'Unanswerable',
}, axis=0)
stats = stats.rename({
    'n': '# of Questions',
    'intent': '# of FAQs',
    'avg_intent_length': 'Avg. FAQ Length',
    'avg_question_length': 'Avg. Question length',
    'avg_answer_length': 'Avg. Answer length',
    'avg_sources_length': 'Avg. # of Sources',
}, axis=1)
stats = stats.loc[['All', 'Answerable', 'Unanswerable']]
stats = stats.rename_axis(None, axis=1)
stats = stats.rename_axis(None, axis=0)
stats = stats.T
stats = stats.round(1)
stats = stats.astype(str)
stats.loc['# of Questions'] = stats.loc['# of Questions'].apply(lambda x: str(int(float(x))))
stats.loc['# of FAQs'] = stats.loc['# of FAQs'].apply(lambda x: str(int(float(x))))
stats
# Out:
#                        All Answerable Unanswerable
# # of Questions          95         76           19
# # of FAQs               36         25           11
# Avg. FAQ Length        9.7        8.9         12.8
# Avg. Question length  43.3       40.5         54.3
# Avg. Answer length    45.5       46.0         43.6
# Avg. # of Sources      1.0        1.3          0.0

# %%
tex = stats \
    .style \
    .format_index("\\textbf{{{}}}", escape="latex", axis=1) \
    .format_index(escape="latex", axis=0) \
    .to_latex(hrules=True, position='t', caption='caption', label='tab:')
print(tex)
# Out:
# \begin{table}[t]
# \caption{caption}
# \label{tab:}
# \begin{tabular}{llll}
# \toprule
#  & \textbf{All} & \textbf{Answerable} & \textbf{Unanswerable} \\
# \midrule
# \# of Questions & 95 & 76 & 19 \\
# \# of FAQs & 36 & 25 & 11 \\
# Avg. FAQ Length & 9.7 & 8.9 & 12.8 \\
# Avg. Question length & 43.3 & 40.5 & 54.3 \\
# Avg. Answer length & 45.5 & 46.0 & 43.6 \\
# Avg. \# of Sources & 1.0 & 1.3 & 0.0 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_queries['intent'].value_counts()
# Out:
# intent
# What are the application deadlines?                                                                                                                  15
# Given my background, will I be accepted?                                                                                                             11
# What are the language requirements and do I meet them?                                                                                                6
# How do I apply?                                                                                                                                       4
# Do I need to submit the IELTS score or is a proof that the bachelor programme was taught in English enough?                                           4
# How does the curriculum look like?                                                                                                                    3
# Is the Master Data Science given entirely in English?                                                                                                 3
# What is the process for late arrivals?                                                                                                                3
# Can I get my documents checked before applying formally?                                                                                              3
# When does the semester start?                                                                                                                         3
# What is the minimum IELTS score for admission?                                                                                                        3
# Does the admission depend on the application time?                                                                                                    3
# Where can I find scholarships?                                                                                                                        2
# Does the university offer student dormitories and where can I get more information?                                                                   2
# Is my 6 semester bachelor degree sufficient for admission?                                                                                            2
# Does the Master Data Science have a minimum grade requirement?                                                                                        2
# Which documents to I need to submit for the application?                                                                                              2
# How do I apply for a higher semester?                                                                                                                 2
# Is my GPA enough for admission?                                                                                                                       2
# What are the admission criteria?                                                                                                                      2
# I got a conditional accept. Do the credit points (CP) I obtain in the courses required for the condition count towards the 120 CP for the Master?     2
# I can not be in Germany this semester. Can I have online courses?                                                                                     2
# Does my language certificate meet the admission criteria?                                                                                             1
# I have not completed all required courses in my bachelor, can I still get admitted?                                                                   1
# What GPA scale is used?                                                                                                                               1
# How many ECTS are for required for admission?                                                                                                         1
# Which language certificates are accepted?                                                                                                             1
# How am I notified about updates to my application?                                                                                                    1
# I got admitted. Can I also come in the next semester?                                                                                                 1
# Do you offer remote learning opportunities? I am living outside Marburg.                                                                              1
# Can I study Data Science while having a full-time job?                                                                                                1
# What is the Masters Data Science about?                                                                                                               1
# When will I receive information about my dormitory application?                                                                                       1
# Where can I get technical support to access my documents in Marvin?                                                                                   1
# What are the tuition fees?                                                                                                                            1
# Can I enroll in German language courses, too?                                                                                                         1
# Name: count, dtype: int64
